# %% [markdown]
# <a href="https://colab.research.google.com/github/Sadaleksej/Work/blob/main/task3_f.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('products_sentiment_train.csv', delimiter=',')
data.head()
# Out:
#    N                                               name  price  \
# 0  1  Чисто российское преступление: Самые громкие и...  540.0
# 1  2       Безлюдное место: Как ловят маньяков в России  539.0
# 2  3                       Письма о добром и прекрасном  238.0
# 3  4  У холмов есть подкаст. 24 истории о серийных у...  715.0
# 4  5       Фундаментальные законы человеческой глупости  605.0
#
#                                                  url  pages  size1  size2  \
# 0  https://www.chitai-gorod.ru/product/chisto-ros...  298.0    1.7   14.6
# 1  https://www.chitai-gorod.ru/product/bezlyudnoe...  264.0    1.4   14.0
# 2  https://www.chitai-gorod.ru/product/pisma-o-do...  192.0    1.5   11.6
# 3  https://www.chitai-gorod.ru/product/u-holmov-e...  448.0    2.7   13.0
# 4  https://www.chitai-gorod.ru/product/fundamenta...  160.0    1.8   13.3
#
#    size3  weight             cover    year  \
# 0   21.6     460  Твёрдый переплёт  2024.0
# 1   21.0     330   Мягкий переплёт  2023.0
# 2   18.1     129   Мягкий переплёт  2024.0
# 3   20.7     430  Твёрдый переплёт  2024.0
# 4   17.3     176  Твёрдый переплёт  2024.0
#
#                                          description
# 0  В новой книге известной правозащитницы и жур...
# 1  С середины 1990-х в небольшом сибирском городе...
# 2  «Письма о добром и прекрасном» – книга, котору...
# 3  Первая книга Тимы и Вали Назаровых, авторов са...
# 4  Впервые остроумно и изящно сформулированы зако...

# %%
data.columns
# Out:
# Index(['N', 'name', 'price', 'url', 'pages', 'size1', 'size2', 'size3',
#        'weight', 'cover', 'year', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# N                int64
# name            object
# price          float64
# url             object
# pages          float64
# size1          float64
# size2          float64
# size3          float64
# weight           int64
# cover           object
# year           float64
# description     object
# dtype: object

# %%
data = data[data['price'].notna()]

# %%
data
# Out:
#          N                                               name   price  \
# 0        1  Чисто российское преступление: Самые громкие и...   540.0
# 1        2       Безлюдное место: Как ловят маньяков в России   539.0
# 2        3                       Письма о добром и прекрасном   238.0
# 3        4  У холмов есть подкаст. 24 истории о серийных у...   715.0
# 4        5       Фундаментальные законы человеческой глупости   605.0
# ...    ...                                                ...     ...
# 1141  1142                              Нечто: сборник статей   773.0
# 1142  1143                              Корпорацию не нагнешь   844.0
# 1143  1144                                   Европа и Евразия  1149.0
# 1144  1145  Исповедь для побежденных : После шестнадцати м...  1989.0
# 1149  1150  Репетиция апокалипсиса. Тайная история атомных...   590.0
#
#                                                     url  pages  size1  size2  \
# 0     https://www.chitai-gorod.ru/product/chisto-ros...  298.0    1.7   14.6
# 1     https://www.chitai-gorod.ru/product/bezlyudnoe...  264.0    1.4   14.0
# 2     https://www.chitai-gorod.ru/product/pisma-o-do...  192.0    1.5   11.6
# 3     https://www.chitai-gorod.ru/product/u-holmov-e...  448.0    2.7   13.0
# 4     https://www.chitai-gorod.ru/product/fundamenta...  160.0    1.8   13.3
# ...                                                 ...    ...    ...    ...
# 1141  https://www.chitai-gorod.ru/product/nechto-sbo...  188.0    1.2   15.2
# 1142  https://www.chitai-gorod.ru/product/korporaciy...  288.0    2.0   13.0
# 1143  https://www.chitai-gorod.ru/product/evropa-i-e...  346.0    2.0   14.0
# 1144  https://www.chitai-gorod.ru/product/ispoved-dl...  346.0    2.0   14.0
# 1149  https://www.chitai-gorod.ru/product/repeticiya...  198.0    1.5   14.6
#
#       size3  weight             cover    year  \
# 0      21.6     460  Твёрдый переплёт  2024.0
# 1      21.0     330   Мягкий переплёт  2023.0
# 2      18.1     129   Мягкий переплёт  2024.0
# 3      20.7     430  Твёрдый переплёт  2024.0
# 4      17.3     176  Твёрдый переплёт  2024.0
# ...     ...     ...               ...     ...
# 1141   21.5     349  Твёрдый переплёт  2021.0
# 1142   20.0      10  Твёрдый переплёт  2021.0
# 1143   21.0     500               NaN  2021.0
# 1144   21.0     500               NaN  2021.0
# 1149   21.6     340  Твёрдый переплёт  2024.0
#
#                                             description
# 0     В новой книге известной правозащитницы и жур...
# 1     С середины 1990-х в небольшом сибирском городе...
# 2     «Письма о добром и прекрасном» – книга, котору...
# 3     Первая книга Тимы и Вали Назаровых, авторов са...
# 4     Впервые остроумно и изящно сформулированы зако...
# ...                                                 ...
# 1141  Константин Николаевич Батюшков - значительная ...
# 1142  Сегодня Алексей Иванов — один из самых успешны...
# 1143                                                NaN
# 1144                                                NaN
# 1149  Эта книга — результат более чем двадцатилетней...
#
# [1145 rows x 12 columns]

# %%
data['volume'] = data['size1']*data['size2']*data['size3']

# %%
data['volume_price']=data['price']/data['volume']

# %%
data['weight_price']=data['price']/data['weight']

# %%
data['page_price']=data['price']/data['pages']

# %%
data
# Out:
#          N                                               name   price  \
# 0        1  Чисто российское преступление: Самые громкие и...   540.0
# 1        2       Безлюдное место: Как ловят маньяков в России   539.0
# 2        3                       Письма о добром и прекрасном   238.0
# 3        4  У холмов есть подкаст. 24 истории о серийных у...   715.0
# 4        5       Фундаментальные законы человеческой глупости   605.0
# ...    ...                                                ...     ...
# 1141  1142                              Нечто: сборник статей   773.0
# 1142  1143                              Корпорацию не нагнешь   844.0
# 1143  1144                                   Европа и Евразия  1149.0
# 1144  1145  Исповедь для побежденных : После шестнадцати м...  1989.0
# 1149  1150  Репетиция апокалипсиса. Тайная история атомных...   590.0
#
#                                                     url  pages  size1  size2  \
# 0     https://www.chitai-gorod.ru/product/chisto-ros...  298.0    1.7   14.6
# 1     https://www.chitai-gorod.ru/product/bezlyudnoe...  264.0    1.4   14.0
# 2     https://www.chitai-gorod.ru/product/pisma-o-do...  192.0    1.5   11.6
# 3     https://www.chitai-gorod.ru/product/u-holmov-e...  448.0    2.7   13.0
# 4     https://www.chitai-gorod.ru/product/fundamenta...  160.0    1.8   13.3
# ...                                                 ...    ...    ...    ...
# 1141  https://www.chitai-gorod.ru/product/nechto-sbo...  188.0    1.2   15.2
# 1142  https://www.chitai-gorod.ru/product/korporaciy...  288.0    2.0   13.0
# 1143  https://www.chitai-gorod.ru/product/evropa-i-e...  346.0    2.0   14.0
# 1144  https://www.chitai-gorod.ru/product/ispoved-dl...  346.0    2.0   14.0
# 1149  https://www.chitai-gorod.ru/product/repeticiya...  198.0    1.5   14.6
#
#       size3  weight             cover    year  \
# 0      21.6     460  Твёрдый переплёт  2024.0
# 1      21.0     330   Мягкий переплёт  2023.0
# 2      18.1     129   Мягкий переплёт  2024.0
# 3      20.7     430  Твёрдый переплёт  2024.0
# 4      17.3     176  Твёрдый переплёт  2024.0
# ...     ...     ...               ...     ...
# 1141   21.5     349  Твёрдый переплёт  2021.0
# 1142   20.0      10  Твёрдый переплёт  2021.0
# 1143   21.0     500               NaN  2021.0
# 1144   21.0     500               NaN  2021.0
# 1149   21.6     340  Твёрдый переплёт  2024.0
#
#                                             description   volume  \
# 0     В новой книге известной правозащитницы и жур...  536.112
# 1     С середины 1990-х в небольшом сибирском городе...  411.600
# 2     «Письма о добром и прекрасном» – книга, котору...  314.940
# 3     Первая книга Тимы и Вали Назаровых, авторов са...  726.570
# 4     Впервые остроумно и изящно сформулированы зако...  414.162
# ...                                                 ...      ...
# 1141  Константин Николаевич Батюшков - значительная ...  392.160
# 1142  Сегодня Алексей Иванов — один из самых успешны...  520.000
# 1143                                                NaN  588.000
# 1144                                                NaN  588.000
# 1149  Эта книга — результат более чем двадцатилетней...  473.040
#
#       volume_price  weight_price  page_price
# 0         1.007252      1.173913    1.812081
# 1         1.309524      1.633333    2.041667
# 2         0.755699      1.844961    1.239583
# 3         0.984076      1.662791    1.595982
# 4         1.460781      3.437500    3.781250
# ...            ...           ...         ...
# 1141      1.971134      2.214900    4.111702
# 1142      1.623077     84.400000    2.930556
# 1143      1.954082      2.298000    3.320809
# 1144      3.382653      3.978000    5.748555
# 1149      1.247252      1.735294    2.979798
#
# [1145 rows x 16 columns]

# %%
v1 = np.percentile (data.volume_price , 95)

# %%
v2 = np.percentile (data.page_price , 95)

# %%
v3 = np.percentile (data.weight_price , 95)

# %%
v1, v2, v3
# Out:
# (3.511460632659837, 7.244578313253011, 5.198758482030658)

# %%
mask = (data['volume_price'].values > v1) & (data['page_price'].values > v2) & (data['weight_price'].values > v3)

# %%
df_new = data.loc[mask]

# %%
df_new.sort_values(by=['volume_price'], ascending=False)
# Out:
#          N                                               name   price  \
# 1038  1039                           Мир, счастье и богатство   889.0
# 974    975  В потоке дней порой бывает сладко, но и случае...  3359.0
# 699    700                                Как я был риелтором   519.0
# 1012  1013                          Как размножаются кентавры  1669.0
# 969    970                                    Живые сплетения  1669.0
# 769    770               Сингапур. Восьмое чудо света. Том 28  5490.0
# 985    986                         У всякой охоты свои заботы   599.0
# 707    708         Провокация. Воззвание и право на переворот   919.0
# 698   https://www.chitai-gorod.ru/product/mozhet-ves...  208.0    1.3   15.2
# 1060  https://www.chitai-gorod.ru/product/u-muzhchin...  104.0    0.6   14.3
# 914   https://www.chitai-gorod.ru/product/marka-s-ce...  513.0    4.9   17.0
# 913   https://www.chitai-gorod.ru/product/i-vy-budet...  584.0    3.5   15.5
# 869   https://www.chitai-gorod.ru/product/vechnoe-le...  220.0    1.5   15.5
# 550   https://www.chitai-gorod.ru/product/vechnoe-le...  220.0    1.5   15.5
# 680   https://www.chitai-gorod.ru/product/reyndzhery...  208.0    1.6   21.2
# 527   https://www.chitai-gorod.ru/product/dorozhi-te...  112.0    1.2   11.0
# 213   https://www.chitai-gorod.ru/product/eta-voyna-...   50.0    0.4   14.0
#
#       size3  weight             cover    year  \
# 1038   21.0      50   Мягкий переплёт  2019.0
# 974    22.0     259  Твёрдый переплёт  2021.0
# 699    20.5      50               NaN  2022.0
# 1012   21.5     170   Мягкий переплёт  2020.0
# 969    23.0     180   Мягкий переплёт  2021.0
# 769    21.5     460               NaN  2019.0
# 985    19.5      90   Мягкий переплёт  2020.0
# 707    18.2     120   Мягкий переплёт  2022.0
# 844    20.0     160   Мягкий переплёт  2023.0
# 849    20.5     172   Мягкий переплёт  2023.0
# 681    26.5     400  Твёрдый переплёт  2024.0
# 870    20.7     400  Твёрдый переплёт  2023.0
# 911    20.5     370  Твёрдый переплёт  2022.0
# 1047   20.4     200   Мягкий переплёт  2019.0
# 772    20.5     140   Мягкий переплёт  2018.0
# 827    28.0     914   Мягкий переплёт  2024.0
# 528    18.0      76   Мягкий переплёт  2024.0
# 523    20.0     170   Мягкий переплёт  2024.0
# 1102   20.5     119   Мягкий переплёт  2015.0
# 916    20.5      59   Мягкий переплёт  2021.0
# 698    21.6     360  Твёрдый переплёт  2023.0
# 1060   21.0     140   Мягкий переплёт  2018.0
# 914    20.8    1096  Твёрдый переплёт  2022.0
# 913    20.7     800  Твёрдый переплёт  2022.0
# 869    21.5     380               NaN  2023.0
# 550    21.5     380               NaN  2023.0
# 680    26.8     610  Твёрдый переплёт  2024.0
# 527    18.0      80               NaN  2024.0
# 213    20.0      70   Мягкий переплёт  2022.0
#
#                                             description    volume  \
# 1038  Вашему вниманию предлагается книга Виктора Сан...    61.740
# 974   Книга не обычная. Кроме содержания текстов, он...   341.000
# 699   Это история женщины, которая всю жизнь стремил...    59.450
# 1012  Книга представляет собой еще один ответ на акт...   210.700
# 969   Книга «Живые сплетения» о двух художниках и ар...   220.800
# 769   Туристы, гуляющие с открытыми ртами по Сингапу...   741.750
# 985   В сборник вошли рассказы об охоте на северных ...    83.070
# 707   Эта небольшая книга написана в форме литератур...   131.040
# 844   В основу этой книги легла запись выступления А...   182.000
# 849   Эта книга - эссе - написана потому, что очень ...   208.075
# 681   Использование в боевых операциях поисково-удар...   559.150
# 870   Чрезвычайно высокие темпы роста сложности, свя...   614.790
# 911   Для желания написать воспоминания всегда есть ...   439.520
# 1047  В этой серии автобиографических рассказов, сме...   295.800
# 772   Как часто в повседневнои? суете мы задумываемс...   148.625
# 827   В книгу известного петербургского художника Ва...   903.000
# 528   Джон Бёрджер (1926–2017) всю жизнь учился смот...   155.520
# 523   Существуют ли пространства, принципиально не о...   260.000
# 1102  Мне всегда больше нравились отрывочные и незак...   148.625
# 916   Как изменение политической системы после краха...    58.630
# 698   На что можно опереться в мире, утонувшем во лж...   426.816
# 1060  Настоящая книга - восьмая из серии "Записки пс...   180.180
# 914   Выступая в тройной роли – писателя, фотографа,...  1732.640
# 913   Новая книга Ю.Г. Гельцера посвящена изучению о...  1122.975
# 869   YouTube-канал "Вечное Лето" знаком многим по я...   499.875
# 550   YouTube-канал "Вечное Лето" знаком многим по я...   499.875
# 680   В книге (включающей материал из наставления «R...   909.056
# 527   В этом сборнике эссе писатель, критик, поэт и ...   237.600
# 213   «Эта война!» – статья, написанная в конце 1939...   112.000
#
#       volume_price  weight_price  page_price
# 1038     14.399093     17.780000   24.694444
# 974       9.850440     12.969112   29.991071
# 699       8.730025     10.380000   17.300000
# 1012      7.921215      9.817647   13.352000
# 969       7.558877      9.272222   17.385417
# 769       7.401416     11.934783   19.195804
# 985       7.210786      6.655556    7.487500
# 707       7.013126      7.658333    9.190000
# 844       6.862637      7.806250   11.151786
# 849       6.531299      7.901163    9.992647
# 681       6.382903      8.922500   35.690000
# 870       6.309472      9.697500   12.844371
# 911       6.209046      7.375676   10.033088
# 1047      6.014199      8.895000   11.118750
# 772       5.846930      6.207143    8.355769
# 827       5.812846      5.742888   31.244048
# 528       5.716307     11.697368    7.937500
# 523       5.611538      8.582353    9.598684
# 1102      5.443230      6.798319    8.606383
# 916       5.440901      5.406780    8.861111
# 698       5.152103      6.108333   10.572115
# 1060      5.100455      6.564286    8.836538
# 914       5.050674      7.984489   17.058480
# 913       5.009907      7.032500    9.633562
# 869       4.503126      5.923684   10.231818
# 550       4.503126      5.923684   10.231818
# 680       3.926051      5.850820   17.158654
# 527       3.741582     11.112500    7.937500
# 213       3.687500      5.900000    8.260000

# %%
df_new['description'] = df_new['description'].str.replace('\n', ' ')
# Out:
# <ipython-input-113-896ca760881d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['description'] = df_new['description'].str.replace('\n', ' ')

# %%
df_new.rename(columns = {'description':'text'}, inplace = True)
# Out:
# <ipython-input-114-220e1d22c63a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.rename(columns = {'description':'text'}, inplace = True)

# %%
df_new['text'].to_csv('out3.csv', index=False)

# %%
count_row = df_new.shape[0]

# %%
count_row
# Out:
# 29

# %%
# !pip install transformers sentencepiece datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import json
import torch
from tqdm.auto import tqdm
from transformers import AutoTokenizer, T5ForConditionalGeneration
from datasets import load_dataset

# %%
df_serv = df_new[['text']]. copy ()

# %%
df_serv
# Out:
#                                                    text
# 213   «Эта война!» – статья, написанная в конце 1939...
# 523   Существуют ли пространства, принципиально не о...
# 527   В этом сборнике эссе писатель, критик, поэт и ...
# 528   Джон Бёрджер (1926–2017) всю жизнь учился смот...
# 550   YouTube-канал "Вечное Лето" знаком многим по я...
# 680   В книге (включающей материал из наставления «R...
# 681   Использование в боевых операциях поисково-удар...
# 698   На что можно опереться в мире, утонувшем во лж...
# 699   Это история женщины, которая всю жизнь стремил...
# 707   Эта небольшая книга написана в форме литератур...
# 769   Туристы, гуляющие с открытыми ртами по Сингапу...
# 772   Как часто в повседневнои? суете мы задумываемс...
# 827   В книгу известного петербургского художника Ва...
# 844   В основу этой книги легла запись выступления А...
# 849   Эта книга - эссе - написана потому, что очень ...
# 869   YouTube-канал "Вечное Лето" знаком многим по я...
# 870   Чрезвычайно высокие темпы роста сложности, свя...
# 911   Для желания написать воспоминания всегда есть ...
# 913   Новая книга Ю.Г. Гельцера посвящена изучению о...
# 914   Выступая в тройной роли – писателя, фотографа,...
# 916   Как изменение политической системы после краха...
# 969   Книга «Живые сплетения» о двух художниках и ар...
# 974   Книга не обычная. Кроме содержания текстов, он...
# 985   В сборник вошли рассказы об охоте на северных ...
# 1012  Книга представляет собой еще один ответ на акт...
# 1038  Вашему вниманию предлагается книга Виктора Сан...
# 1047  В этой серии автобиографических рассказов, сме...
# 1060  Настоящая книга - восьмая из серии "Записки пс...
# 1102  Мне всегда больше нравились отрывочные и незак...

# %%
data = []
for index, row in df_serv.iterrows():
    entry = {
        "N": index,
        "text": row[0]
    }
    data.append(entry)


with open('output.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)
# Out:
# <ipython-input-122-110f70a2961f>:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   "text": row[0]

# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
MODEL_NAME = 'cointegrated/rut5-base-absum'
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
model.cpu();
model.eval();
# Out:
# config.json:   0%|          | 0.00/753 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/977M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/315 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/828k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
def summarize(
    text, n_words=None, compression=None,
    max_length=1000, num_beams=3, do_sample=False, repetition_penalty=10.0,
    **kwargs
):
    """
    Summarize the text
    The following parameters are mutually exclusive:
    - n_words (int) is an approximate number of words to generate.
    - compression (float) is an approximate length ratio of summary and original text.
    """
    if n_words:
        text = '[{}] '.format(n_words) + text
    elif compression:
        text = '[{0:.1g}] '.format(compression) + text
    x = tokenizer(text, return_tensors='pt', padding=True).to(model.device)
    with torch.inference_mode():
        out = model.generate(
            **x,
            max_length=max_length, num_beams=num_beams,
            do_sample=do_sample, repetition_penalty=repetition_penalty,
            **kwargs
        )
    return tokenizer.decode(out[0], skip_special_tokens=True)

# %%
df_serv['disc_new'] = df_serv['text'].apply(summarize)

# %%
df_serv
# Out:
#                                                    text  \
# 213   «Эта война!» – статья, написанная в конце 1939...
# 523   Существуют ли пространства, принципиально не о...
# 527   В этом сборнике эссе писатель, критик, поэт и ...
